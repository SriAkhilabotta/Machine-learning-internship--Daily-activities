# %%
a=[1,2,3,4,5]
a.append(6)
print(a)#adds last element
# Out:
# [1, 2, 3, 4, 5, 6]

# %%
a=[1,2,3,4,5]
a.pop(0)
print(a)#remove last element
# Out:
# [2, 3, 4, 5]

# %%
a=[1,2,3,4,5]
a.clear()
print(a)#clears everything
# Out:
# []

# %%
a=[1,2,3,4,5]
a.insert(0,10)
print(a)#inserts postiton,value
# Out:
# [10, 1, 2, 3, 4, 5]

# %%
a=[2,1,4]
a.index(4)#checks the index of given value
# Out:
# 2

# %%
a=[1,2,3,4,5]
sum(a)#sum chestadi
# Out:
# 15

# %%
a=[1,2,3,4,5]
min(a)#finds the minmum of numbers
# Out:
# 1

# %%
a=[1,2,3,4,5]
max(a)#finds maximm of numbers
# Out:
# 5

# %%
a=[1,2,3,4,5]
a.count(3) #manaki em number kavalo ahh number alredy repeate ayyindho ledho cheptadhi
# Out:
# 1

# %%
a=[1,2,3,4,5]
a.remove(5)
print(a)#manaki ka kavalsina element ni remove cheskovach
# Out:
# [1, 2, 3, 4]

# %%
a=[1,2,3,4,5]
len(a)#overall lenght entha undho define chestadi
# Out:
# 5

# %%
a=[1,2,3,4,5]
a.reverse()
print(a)# values ni reverse lo print chestadi
# Out:
# [5, 4, 3, 2, 1]

# %%
a=[1,2,3,4,5]
a[::-1]#reverse ila kuda use chesataam method use cheykunda
# Out:
# [5, 4, 3, 2, 1]

# %%
a=[5,3,2,6,8,34]

a.sort()
print(a)#sort ante ascending order lo pedtadi
# Out:
# [2, 3, 5, 6, 8, 34]
