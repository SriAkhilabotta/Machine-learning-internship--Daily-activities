# %%
import pandas as pd
df=pd.read_csv(r"C:\Users\SRI AKHILA\Book1.csv")
df
# Out:
#         city  humidity  temp
# 0        Hyd      34.0  56.0
# 1        kkd      45.0  67.0
# 2        vzg      56.0   NaN
# 3        Hyd      23.0  32.0
# 4        vzg      34.0  89.0
# 5        kkd       NaN  67.0
# 6  bangalore      78.0  67.0

# %%
df.max()
# Out:
# city         vzg
# humidity    78.0
# temp        89.0
# dtype: object

# %%
df.min()
# Out:
# city         Hyd
# humidity    23.0
# temp        32.0
# dtype: object

# %%
df["temp"].mean()
# Out:
# 63.0

# %%
df["humidity"].mean()
# Out:
# 45.0

# %%
df["temp"].mode()
# Out:
# 0    67.0
# Name: temp, dtype: float64

# %%
df["temp"].median()
# Out:
# 67.0

# %%
df["temp"].var()
# Out:
# 346.8

# %%
df["temp"].std()
# Out:
# 18.62256695517565
