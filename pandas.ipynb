# %% [markdown]
# # what is pandas

# %% [markdown]
# pandas is a python library used

# %% [markdown]
# # Importing pandas

# %%
import pandas as pd
import numpy as np
pd.__version__
# Out:
# '2.0.3'

# %% [markdown]
# # Pandas data structure::

# %% [markdown]
# # series- one dimensional column
# # DataFrame-Table with rows+columns

# %%
s=pd.Series([10,20,30])
s
# Out:
# 0    10
# 1    20
# 2    30
# dtype: int64

# %%
df=pd.DataFrame({
    "name":["Neelima","Akhila"],
    "Age":[20,19],
    "Location":["kakinadaa","Pithapuram"]})
df
# Out:
#       name  Age    Location
# 0  Neelima   20   kakinadaa
# 1   Akhila   19  Pithapuram

# %% [markdown]
# # Reading Data(CSV)

# %%
df=pd.DataFrame({
    "name":["Akhila","Sahithi","Akhila","neelima"],
    "age":[91,23,91,23]})
df
# Out:
#       name  age
# 0   Akhila   91
# 1  Sahithi   23
# 2   Akhila   91
# 3  neelima   23

# %%
df.duplicated()
# Out:
# 0    False
# 1    False
# 2     True
# 3    False
# dtype: bool

# %%
df[df.duplicated()]
# Out:
#      name  age
# 2  Akhila   91

# %%
df=df.drop_duplicates()
df
# Out:
#       name  age
# 0   Akhila   91
# 1  Sahithi   23
# 3  neelima   23
